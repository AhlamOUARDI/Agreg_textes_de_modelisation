# %%
from random import randrange
import numpy as np
import matplotlib.pyplot as plt
N = 100
b = 0
list_pos = [b]
for i in range(1, N+1):
    c = randrange(2)
    if c == 0:
        b -= 1
        list_pos.append(b)
    else:
        b += 1
        list_pos.append(b)
t = np.arange(len(list_pos))
s = np.array(list_pos)
list_retour_0 = [index for index, value in enumerate(list_pos) if value == 0]
plt.figure(figsize=(8,8))
plt.plot(t, s)
for z in list_retour_0[1:]:
    plt.plot(t[z], s[z], '-r.')
plt.xlabel('Temps', fontdict=font)
plt.ylabel('Position', fontdict=font)
plt.title('La marche aléatoire sur Z et le retour en 0', fontdict=font)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_138492\855940096.py in <module>
#      20 for z in list_retour_0[1:]:
#      21     plt.plot(t[z], s[z], '-r.')
# ---> 22 plt.xlabel('Temps', fontdict=font)
#      23 plt.ylabel('Position', fontdict=font)
#      24 plt.title('La marche aléatoire sur Z et le retour en 0', fontdict=font)
#
# NameError: name 'font' is not defined

# %%
randrange(2)
# Out:
# 1
